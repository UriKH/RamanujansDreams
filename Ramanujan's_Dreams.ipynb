# %%
# !pip install git+https://github.com/UriKH/RamanujansDreams.git
# Out:
# Collecting git+https://github.com/UriKH/RamanujansDreams.git
#   Cloning https://github.com/UriKH/RamanujansDreams.git to c:\users\urikh\appdata\local\temp\pip-req-build-8_blux73
#   Resolved https://github.com/UriKH/RamanujansDreams.git to commit 40aae7717c193b6387384da75f4d5da9e59e6074
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: peewee in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (3.18.2)
# Requirement already satisfied: sympy in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (1.14.0)
# Collecting ramanujantools@ git+https://github.com/RamanujanMachine/ramanujantools.git (from ramanujans-dreams==0.0.1)
#   Cloning https://github.com/RamanujanMachine/ramanujantools.git to c:\users\urikh\appdata\local\temp\pip-install-zf4oiy_0\ramanujantools_58fa0ee417094682a74e90db5cde61ec
#   Resolved https://github.com/RamanujanMachine/ramanujantools.git to commit fcf93debd0be44ed14d208d41bf010d37e47603f
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (3.10.5)
# Requirement already satisfied: numpy in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (2.3.2)
# Requirement already satisfied: mpmath in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (1.3.0)
# Requirement already satisfied: networkx in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (3.5)
# Requirement already satisfied: tqdm in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (4.67.1)
# Requirement already satisfied: numba in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (0.62.1)
# Requirement already satisfied: requests in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (2.32.5)
# Requirement already satisfied: pandas in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (2.3.2)
# Requirement already satisfied: scipy in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (1.16.2)
# Requirement already satisfied: pulp in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujans-dreams==0.0.1) (3.3.0)
# Collecting LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main (from ramanujans-dreams==0.0.1)
#   Cloning https://github.com/RamanujanMachine/LIReC.git (to revision main) to c:\users\urikh\appdata\local\temp\pip-install-zf4oiy_0\lirec_e8b2bdc95f3d40fba011ada21efe3699
#   Resolved https://github.com/RamanujanMachine/LIReC.git to commit f0c2b42725294f39b8a11d9b9c6d26c363829b3e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: psycopg2>=2.8.6 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main->ramanujans-dreams==0.0.1) (2.9.10)
# Requirement already satisfied: sqlalchemy>=2.0.5 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main->ramanujans-dreams==0.0.1) (2.0.43)
# Requirement already satisfied: gmpy2>=2.1.5 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main->ramanujans-dreams==0.0.1) (2.2.1)
# Requirement already satisfied: python-flint>=0.7.0 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from ramanujantools@ git+https://github.com/RamanujanMachine/ramanujantools.git->ramanujans-dreams==0.0.1) (0.7.1)
# Requirement already satisfied: greenlet>=1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from sqlalchemy>=2.0.5->LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main->ramanujans-dreams==0.0.1) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from sqlalchemy>=2.0.5->LIReC@ git+https://github.com/RamanujanMachine/LIReC.git@main->ramanujans-dreams==0.0.1) (4.15.0)
# Requirement already satisfied: colorama in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from tqdm->ramanujans-dreams==0.0.1) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (25.0)
# Requirement already satisfied: pillow>=8 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from matplotlib->ramanujans-dreams==0.0.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->ramanujans-dreams==0.0.1) (1.17.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from numba->ramanujans-dreams==0.0.1) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from pandas->ramanujans-dreams==0.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from pandas->ramanujans-dreams==0.0.1) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from requests->ramanujans-dreams==0.0.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from requests->ramanujans-dreams==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from requests->ramanujans-dreams==0.0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\ramanujan machine\rt-cmf-sys\.venv\lib\site-packages (from requests->ramanujans-dreams==0.0.1) (2025.8.3)
#   Running command git clone --filter=blob:none --quiet https://github.com/UriKH/RamanujansDreams.git 'C:\Users\urikh\AppData\Local\Temp\pip-req-build-8_blux73'
#   hint: core.useBuiltinFSMonitor=true is deprecated;please set core.fsmonitor=true instead
#   hint: Disable this message with "git config set advice.useCoreFSMonitorConfig false"
#   Running command git clone --filter=blob:none --quiet https://github.com/RamanujanMachine/ramanujantools.git 'C:\Users\urikh\AppData\Local\Temp\pip-install-zf4oiy_0\ramanujantools_58fa0ee417094682a74e90db5cde61ec'
#   hint: core.useBuiltinFSMonitor=true is deprecated;please set core.fsmonitor=true instead
#   hint: Disable this message with "git config set advice.useCoreFSMonitorConfig false"
#   Running command git clone --filter=blob:none --quiet https://github.com/RamanujanMachine/LIReC.git 'C:\Users\urikh\AppData\Local\Temp\pip-install-zf4oiy_0\lirec_e8b2bdc95f3d40fba011ada21efe3699'
#   hint: core.useBuiltinFSMonitor=true is deprecated;please set core.fsmonitor=true instead
#   hint: Disable this message with "git config set advice.useCoreFSMonitorConfig false"
#
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Imports and configuration
# From `dreamer` are available the sytem itself, its configurations and the different stages.

# %%
from dreamer import System, config
from dreamer import analysis, search, extraction
from dreamer.loading import *

import sympy as sp # import for fraction usage

# %% [markdown]
# Default behavior is changable via the `config.configure()` and the usage of the different stages (configurations are grouped by stage).

# %%
def trajectory_compute_func(d):
  return max(10 ** (d-1) / 2, 10)

config.configure(
    system={
        'EXPORT_CMFS': './mycmfs',                          # export CMF as objects to directory: ./mycmfs
        'EXPORT_ANALYSIS_PRIORITIES': './myshards',         # export shards found in analysis into: ./myshards
        'EXPORT_SEARCH_RESULTS': './mysearchresults'        # export the search results into: ./mysearchresults
    },
    analysis={
        'IDENTIFY_THRESHOLD': 0.2,          # ignore shards with less than 20% identified trajectories as converge
                                            # to the constant
        'NUM_TRAJECTORIES_FROM_DIM': trajectory_compute_func  # number of trajectories to be auto generated in analysis
    },
    search={
        'NUM_TRAJECTORIES_FROM_DIM': trajectory_compute_func  # number of trajectories to be auto generated in search if needed by the module
    }
)

# %% [markdown]
# You can also view the configurations like so:

# %%
# view system configs
print(config.system.display())
# Out:
# +----------------------------+--------------------------------------------------------------+
# | Property                   | Value                                                        |
# +----------------------------+--------------------------------------------------------------+
# | CONSTANTS                  | []                                                           |
# | MODULE_ERROR_SHOW_TRACE    | True                                                         |
# | TQDM_CONFIG                | {'bar_format': '{desc:<40}     {bar} | {elapsed} {rate_fm... |
# | LOGGING_BUFFER_SIZE        | 150                                                          |
# | USE_LIReC                  | True                                                         |
# | EXPORT_CMFS                | ./mycmfs                                                     |
# | EXPORT_ANALYSIS_PRIORITIES | ./myshards                                                   |
# | EXPORT_SEARCH_RESULTS      | ./mysearchresults                                            |
# +----------------------------+--------------------------------------------------------------+

# %%
# view analysis configs
print(config.analysis.display())
# Out:
# +----------------------------+----------------------------------------------------------+
# | Property                   | Value                                                    |
# +----------------------------+----------------------------------------------------------+
# | USE_CACHING                | True                                                     |
# | NUM_TRAJECTORIES_FROM_DIM  | <function trajectory_compute_func at 0x000001E4B9C89940> |
# | IDENTIFY_THRESHOLD         | 0.2                                                      |
# | PRINT_FOR_EVERY_SEARCHABLE | True                                                     |
# | SHOW_START_POINT           | True                                                     |
# | SHOW_SEARCHABLE            | False                                                    |
# | USE_LIReC                  | True                                                     |
# | ANALYZE_LIMIT              | False                                                    |
# | ANALYZE_EIGEN_VALUES       | False                                                    |
# | ANALYZE_GCD_SLOPE          | False                                                    |
# +----------------------------+----------------------------------------------------------+

# %% [markdown]
# ### System execution
# Run the system on a ${}_2F_1$ with $z=\frac{1}{2}$ ($\pi$'s 3D simple CMF) with the basic shard analyzer and searcher (all trajectory) modules.
#
# Note that in order to use the ${}_pF_q$ we need to tell for which constant we search inside the CMF and give a shift type of start points - i.e. all start points in this case are of the form $(x, y, z+\frac{1}{2})$ where $x,y,z\in\mathbb{Z}$.
#
# #### Constants:
# - To import known constants use: `from dreamer import pi, e, euler_gamma, catalan`
# - To import known functions:
#   ```
#   from dreamer import zeta, log, sqrt, power
#
#   log_2 = log(2)
#   zeta_3 = zeta(3)
#   sqrt_2 = sqrt(2)
#   pi_p_2 = power(pi, 2)
#   ```
# - If constant is not provided by the system you can add it yourself by simply:
#   ```
#   from dreamer import Constant
#
#   my_cons = Constant('const-name', <value using sympy>)
#   ```

# %%
from dreamer import pi, zeta
import sys

System(
    if_srcs=[pFq_formatter(pi, 2, 1, sp.Rational(1, 2), [0, 0, sp.Rational(1, 2)])],
    extractor=extraction.extractor.ShardExtractorMod,
    analyzers=[analysis.AnalyzerModV1],
    searcher=search.SearcherModV1
).run(constants=[pi])
# Out:
# [INFO] Loading CMFs ...
#
# [INFO] CMFs for pi exported to ./mycmfs\pi
#
# [INFO] Searching for pi using inspiration functions:
# 1. ShiftCMF(cmf=pFq((2, 1, 1/2)), shift=Position({x0: 0, x1: 0, y0: 1/2}), selected_points=None, only_selected=False, raw=False)
# Extracting shards for "pi"                                                     | 00:00 ?it/s (0.00%)
# Computing shards                                                               | 00:00 ?it/s (0.00%)
#
# Computing shard encodings                                                      | 00:00 ?it/s (0.00%)
#
#
# Extracting shards for "pi"                                                     | 00:00 ?it/s (0.00%)
# Computing shards                                                               | 00:00 ?it/s (0.00%)
# [INFO] In CMF no. 1: found 2 hyperplanes and 4 shards
# Creating shard objects                                                         | 00:00 ?it/s (0.00%)
#
#
# Computing shards                             ███████████████████████████ | 00:00  1.76it/s (100.00%)
# Analyzing constants and their CMFs                                             | 00:00 ?it/s (0.00%)
# ================================================================== Analyzing for pi ==================================================================
# Analyzing shards                                                               | 00:00 ?it/s (0.00%)
#
# Analyzing constants and their CMFs                                             | 00:00 ?it/s (0.00%)
# ========== SHARD NO. 1 ==========
#
# Analyzing constants and their CMFs                                             | 00:00 ?it/s (0.00%)
# [INFO] Chosen shard start point: Position({x0: -1, x1: -1, y0: 5/2})
# Traceback (most recent call last):
#   File "C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\utils\schemes\module.py", line 27, in wrapper
#     return func(mod, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\analysis\analyzers\serial_analyzer\analyzer_mod.py", line 50, in execute
#     dms = analyzer.search()
#           ^^^^^^^^^^^^^^^^^
#   File "C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\analysis\analysis_methods\serial_analyzer.py", line 45, in search
#     dm = searcher.search(
#          ^^^^^^^^^^^^^^^^
#   File "C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\search\methods\serial\serial_searcher.py", line 78, in search
#     for res in results:
#                ^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\process.py", line 642, in _chain_from_iterable_of_lists
#     for element in iterable:
#                    ^^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
# [ERROR] In module AnalyzerModV1 [version: 1] caught BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\utils\schemes\module.py:27, in CatchErrorInModule.__call__.<locals>.wrapper(mod, *args, **kwargs)
#      26 try:
# ---> 27     return func(mod, *args, **kwargs)
#      28 except Exception as e:
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\analysis\analyzers\serial_analyzer\analyzer_mod.py:50, in AnalyzerModV1.execute(self)
#      49 analyzer = Analyzer(constant, shards)
# ---> 50 dms = analyzer.search()
#      51 queue.append(analyzer.prioritize(dms, PRIORITIZATION_RANKS))
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\analysis\analysis_methods\serial_analyzer.py:45, in Analyzer.search(self)
#      44 searcher = SerialSearcher(shard, self.const, use_LIReC=analysis_config.USE_LIReC)
# ---> 45 dm = searcher.search(
#      46     start,
#      47     find_limit=analysis_config.ANALYZE_LIMIT,
#      48     find_gcd_slope=analysis_config.ANALYZE_GCD_SLOPE,
#      49     find_eigen_values=analysis_config.ANALYZE_EIGEN_VALUES,
#      50     trajectory_generator=analysis_config.NUM_TRAJECTORIES_FROM_DIM
#      51 )
#      53 identified = dm.identified_percentage
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\search\methods\serial\serial_searcher.py:78, in SerialSearcher.search(self, starts, find_limit, find_eigen_values, find_gcd_slope, trajectory_generator)
#      69 results = self.pool.map(
#      70     partial(
#      71         self.space.compute_trajectory_data,
#    (...)     76     ),
#      77     traj_lst, start_lst, chunksize=search_config.SEARCH_VECTOR_CHUNK)
# ---> 78 for res in results:
#      79     if res:
#
# File C:\Python312\Lib\concurrent\futures\process.py:642, in _chain_from_iterable_of_lists(iterable)
#     637 """
#     638 Specialized implementation of itertools.chain.from_iterable.
#     639 Each item in *iterable* should be a list.  This function is
#     640 careful not to keep references to yielded objects.
#     641 """
# --> 642 for element in iterable:
#     643     element.reverse()
#
# File C:\Python312\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     618 if timeout is None:
# --> 619     yield _result_or_cancel(fs.pop())
#     620 else:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     316 try:
# --> 317     return fut.result(timeout)
#     318 finally:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 9
#       1 from dreamer import pi, zeta
#       2 import sys
#       4 System(
#       5     if_srcs=[pFq_formatter(pi, 2, 1, sp.Rational(1, 2), [0, 0, sp.Rational(1, 2)])],
#       6     extractor=extraction.extractor.ShardExtractorMod,
#       7     analyzers=[analysis.AnalyzerModV1],
#       8     searcher=search.SearcherModV1
# ----> 9 ).run(constants=[pi])
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\system\system.py:93, in System.run(self, constants)
#      88     shard_dict = self.extractor(cmf_data).execute()
#      90 # =======================================================
#      91 # ANALYSIS STAGE - analyzes shards and prioritize search
#      92 # =======================================================
# ---> 93 priorities = self.__analysis_stage(shard_dict)
#      94 Logger.timer_summary()
#      96 # Store priorities to be used in the search stage and future runs
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\system\system.py:199, in System.__analysis_stage(self, cmf_data)
#     196         if const_shards:
#     197             cmf_data[const_shards[0].const] = const_shards
# --> 199 analyzers_results = [analyzer(cmf_data).execute() for analyzer in analyzers]
#     200 priorities = self.__aggregate_analyzers(analyzers_results)
#     202 # add unprioritized elements to the end
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\utils\schemes\module.py:46, in CatchErrorInModule.__call__.<locals>.wrapper(mod, *args, **kwargs)
#      43 try:
#      44     # This will throw an exception instead of exit if you are using a jupyter Notebook
#      45     __IPYTHON__
# ---> 46     raise Exception('Stopping...')
#      47 except NameError:
#      48     exit(1)
#
# Exception: Stopping...

# %% [markdown]
# ### Let's search only specific shards
# In order to do so just add to the specific function you choose the selected points.
#
# For example:

# %%
# from dreamer import pi, zeta
# import sys

System(
    if_srcs=[pFq_formatter(pi, 2, 1, sp.Rational(1, 2), [0, 0, sp.Rational(1, 2)], [(-1, -1, 2)], True)],
    extractor=extraction.extractor.ShardExtractorMod,
    analyzers=[analysis.AnalyzerModV1],
    searcher=search.SearcherModV1
).run(constants=[pi])
# Out:
# [INFO] Loading CMFs ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       1 # from dreamer import pi, zeta
#       2 # import sys
#       4 System(
#       5     if_srcs=[pFq_formatter(pi, 2, 1, sp.Rational(1, 2), [0, 0, sp.Rational(1, 2)], [(-1, -1, 2)], True)],
#       6     extractor=extraction.extractor.ShardExtractorMod,
#       7     analyzers=[analysis.AnalyzerModV1],
#       8     searcher=search.SearcherModV1
# ----> 9 ).run(constants=[pi])
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\system\system.py:56, in System.run(self, constants)
#      51 constants = self.__validate_constants(constants)
#      53 # ======================================================
#      54 # LOAD STAGE - loading constants (and optional storage)
#      55 # ======================================================
# ---> 56 cmf_data = self.__loading_stage(constants)
#      57 if path := sys_config.EXPORT_CMFS:
#      58     os.makedirs(path, exist_ok=True)
#
# File C:\Dev\Ramanujan Machine\RT-CMF-sys\dreamer\system\system.py:140, in System.__loading_stage(self, constants)
#     138     cmf_data[Constant.get_constant(db.split('/')[-2])].add(shift_cmf)
#     139 elif isinstance(db, Formatter):
# --> 140     cmf_data[Constant.get_constant(db.const)].add(db.to_cmf())
#     141 else:
#     142     raise ValueError(f'Not a known format: {db} (accepts only str | DBModScheme | Formatter)')
#
# File <string>:3, in __hash__(self)
#
# TypeError: unhashable type: 'list'
